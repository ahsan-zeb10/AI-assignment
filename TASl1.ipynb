# %%
# Tree Node Definition
class TreeNode:
    def __init__(self, val):
        self.val = val
        self.left = None
        self.right = None

# Breadth-First Search (BFS) on a Tree
def tree_bfs(root):
    if not root:
        return

    queue = [root]
    result = []

    while queue:
        current = queue.pop(0)
        result.append(current.val)

        if current.left:
            queue.append(current.left)
        if current.right:
            queue.append(current.right)

    return result

# Depth-First Search (DFS) on a Tree (Preorder)
def tree_dfs_preorder(root):
    if not root:
        return []

    result = []
    stack = [root]

    while stack:
        current = stack.pop()
        result.append(current.val)

        if current.right:
            stack.append(current.right)
        if current.left:
            stack.append(current.left)

    return result

# Depth-First Search (DFS) on a Tree (Inorder)
def tree_dfs_inorder(root):
    if not root:
        return []

    result = []
    stack = []
    current = root

    while current or stack:
        while current:
            stack.append(current)
            current = current.left

        current = stack.pop()
        result.append(current.val)
        current = current.right

    return result

# Depth-First Search (DFS) on a Tree (Postorder)
def tree_dfs_postorder(root):
    if not root:
        return []

    result = []
    stack1 = [root]
    stack2 = []

    while stack1:
        current = stack1.pop()
        stack2.append(current)

        if current.left:
            stack1.append(current.left)
        if current.right:
            stack1.append(current.right)

    while stack2:
        result.append(stack2.pop().val)

    return result

# %%
from collections import deque

# Graph Node Definition
class GraphNode:
    def __init__(self, val):
        self.val = val
        self.neighbors = []

# Breadth-First Search (BFS) on a Graph
def graph_bfs(start):
    if not start:
        return

    queue = deque([start])
    visited = set()
    result = []

    while queue:
        current = queue.popleft()

        if current in visited:
            continue

        result.append(current.val)
        visited.add(current)

        for neighbor in current.neighbors:
            if neighbor not in visited:
                queue.append(neighbor)

    return result

# Depth-First Search (DFS) on a Graph
def graph_dfs(start):
    if not start:
        return []

    visited = set()
    result = []

    def dfs_helper(node):
        if node in visited:
            return

        visited.add(node)
        result.append(node.val)

        for neighbor in node.neighbors:
            dfs_helper(neighbor)

    dfs_helper(start)

    return result

# %% [markdown]
# TASK **2**

# %%
import random

class TreeNode:
    def __init__(self, val):
        self.val = val
        self.left = None
        self.right = None

def insert_node(root, val):
    if not root:
        return TreeNode(val)

    if val < root.val:
        root.left = insert_node(root.left, val)
    else:
        root.right = insert_node(root.right, val)

    return root

def build_tree(numbers):
    if not numbers:
        return None

    root = None
    for num in numbers:
        root = insert_node(root, num)

    return root

# Example usage
numbers_1000 = [random.randint(1, 1000) for _ in range(1000)]
tree_1000 = build_tree(numbers_1000)

numbers_40000 = [random.randint(1, 40000) for _ in range(40000)]
tree_40000 = build_tree(numbers_40000)

numbers_80000 = [random.randint(1, 80000) for _ in range(80000)]
tree_80000 = build_tree(numbers_80000)

numbers_200000 = [random.randint(1, 200000) for _ in range(200000)]
tree_200000 = build_tree(numbers_200000)

numbers_1000000 = [random.randint(1, 1000000) for _ in range(1000000)]
tree_1000000 = build_tree(numbers_1000000)

# Print the tree structure
def print_tree(root):
    if root:
        print(root.val)
        print_tree(root.left)
        print_tree(root.right)

print("Tree for numbers_1000:")
print_tree(tree_1000)

print("Tree for numbers_40000:")
print_tree(tree_40000)

print("Tree for numbers_80000:")
print_tree(tree_80000)

print("Tree for numbers_200000:")
print_tree(tree_200000)

print("Tree for numbers_1000000:")
print_tree(tree_1000000)
# Out:
# Streaming output truncated to the last 5000 lines.
# 25595
# 25593
# 25591
# 25593
# 25602
# 25601
# 25598
# 25595
# 25595
# 25598
# 25601
# 25605
# 25604
# 25609
# 25607
# 25606
# 25606
# 25625
# 25622
# 25612
# 25621
# 25616
# 25615
# 25615
# 25620
# 25619
# 25621
# 25623
# 25622
# 25633
# 25632
# 25626
# 25630
# 25628
# 25633
# 25642
# 25639
# 25637
# 25634
# 25634
# 25636
# 25634
# 25637
# 25637
# 25639
# 25639
# 25641
# 25692
# 25665
# 25659
# 25651
# 25647
# 25646
# 25643
# 25642
# 25642
# 25642
# 25644
# 25643
# 25644
# 25646
# 25649
# 25650
# 25658
# 25656
# 25651
# 25651
# 25653
# 25654
# 25663
# 25661
# 25659
# 25661
# 25661
# 25662
# 25661
# 25662
# 25663
# 25664
# 25684
# 25671
# 25668
# 25665
# 25667
# 25665
# 25665
# 25670
# 25669
# 25669
# 25677
# 25672
# 25675
# 25676
# 25676
# 25678
# 25677
# 25677
# 25677
# 25678
# 25682
# 25678
# 25682
# 25689
# 25687
# 25691
# 25690
# 25692
# 25707
# 25692
# 25705
# 25692
# 25695
# 25698
# 25697
# 25701
# 25698
# 25703
# 25705
# 25722
# 25713
# 25712
# 25709
# 25719
# 25716
# 25715
# 25718
# 25720
# 25722
# 25722
# 25726
# 25723
# 25723
# 25725
# 25730
# 25729
# 25726
# 25732
# 25731
# 25744
# 25738
# 25733
# 25734
# 25733
# 25734
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-d204ca06a309> in <cell line: 60>()
#      58
#      59 print("Tree for numbers_80000:")
# ---> 60 print_tree(tree_80000)
#      61
#      62 print("Tree for numbers_200000:")
#
# <ipython-input-6-d204ca06a309> in print_tree(root)
#      49         print(root.val)
#      50         print_tree(root.left)
# ---> 51         print_tree(root.right)
#      52
#      53 print("Tree for numbers_1000:")
#
# <ipython-input-6-d204ca06a309> in print_tree(root)
#      48     if root:
#      49         print(root.val)
# ---> 50         print_tree(root.left)
#      51         print_tree(root.right)
#      52
#
# <ipython-input-6-d204ca06a309> in print_tree(root)
#      49         print(root.val)
#      50         print_tree(root.left)
# ---> 51         print_tree(root.right)
#      52
#      53 print("Tree for numbers_1000:")
#
# <ipython-input-6-d204ca06a309> in print_tree(root)
#      49         print(root.val)
#      50         print_tree(root.left)
# ---> 51         print_tree(root.right)
#      52
#      53 print("Tree for numbers_1000:")
#
# <ipython-input-6-d204ca06a309> in print_tree(root)
#      48     if root:
#      49         print(root.val)
# ---> 50         print_tree(root.left)
#      51         print_tree(root.right)
#      52
#
# <ipython-input-6-d204ca06a309> in print_tree(root)
#      48     if root:
#      49         print(root.val)
# ---> 50         print_tree(root.left)
#      51         print_tree(root.right)
#      52
#
# <ipython-input-6-d204ca06a309> in print_tree(root)
#      48     if root:
#      49         print(root.val)
# ---> 50         print_tree(root.left)
#      51         print_tree(root.right)
#      52
#
# <ipython-input-6-d204ca06a309> in print_tree(root)
#      48     if root:
#      49         print(root.val)
# ---> 50         print_tree(root.left)
#      51         print_tree(root.right)
#      52
#
# <ipython-input-6-d204ca06a309> in print_tree(root)
#      49         print(root.val)
#      50         print_tree(root.left)
# ---> 51         print_tree(root.right)
#      52
#      53 print("Tree for numbers_1000:")
#
# <ipython-input-6-d204ca06a309> in print_tree(root)
#      48     if root:
#      49         print(root.val)
# ---> 50         print_tree(root.left)
#      51         print_tree(root.right)
#      52
#
# <ipython-input-6-d204ca06a309> in print_tree(root)
#      48     if root:
#      49         print(root.val)
# ---> 50         print_tree(root.left)
#      51         print_tree(root.right)
#      52
#
# <ipython-input-6-d204ca06a309> in print_tree(root)
#      49         print(root.val)
#      50         print_tree(root.left)
# ---> 51         print_tree(root.right)
#      52
#      53 print("Tree for numbers_1000:")
#
# <ipython-input-6-d204ca06a309> in print_tree(root)
#      48     if root:
#      49         print(root.val)
# ---> 50         print_tree(root.left)
#      51         print_tree(root.right)
#      52
#
# <ipython-input-6-d204ca06a309> in print_tree(root)
#      49         print(root.val)
#      50         print_tree(root.left)
# ---> 51         print_tree(root.right)
#      52
#      53 print("Tree for numbers_1000:")
#
# <ipython-input-6-d204ca06a309> in print_tree(root)
#      48     if root:
#      49         print(root.val)
# ---> 50         print_tree(root.left)
#      51         print_tree(root.right)
#      52
#
# <ipython-input-6-d204ca06a309> in print_tree(root)
#      49         print(root.val)
#      50         print_tree(root.left)
# ---> 51         print_tree(root.right)
#      52
#      53 print("Tree for numbers_1000:")
#
# <ipython-input-6-d204ca06a309> in print_tree(root)
#      49         print(root.val)
#      50         print_tree(root.left)
# ---> 51         print_tree(root.right)
#      52
#      53 print("Tree for numbers_1000:")
#
# <ipython-input-6-d204ca06a309> in print_tree(root)
#      49         print(root.val)
#      50         print_tree(root.left)
# ---> 51         print_tree(root.right)
#      52
#      53 print("Tree for numbers_1000:")
#
# <ipython-input-6-d204ca06a309> in print_tree(root)
#      48     if root:
#      49         print(root.val)
# ---> 50         print_tree(root.left)
#      51         print_tree(root.right)
#      52
#
# <ipython-input-6-d204ca06a309> in print_tree(root)
#      49         print(root.val)
#      50         print_tree(root.left)
# ---> 51         print_tree(root.right)
#      52
#      53 print("Tree for numbers_1000:")
#
# <ipython-input-6-d204ca06a309> in print_tree(root)
#      49         print(root.val)
#      50         print_tree(root.left)
# ---> 51         print_tree(root.right)
#      52
#      53 print("Tree for numbers_1000:")
#
# <ipython-input-6-d204ca06a309> in print_tree(root)
#      48     if root:
#      49         print(root.val)
# ---> 50         print_tree(root.left)
#      51         print_tree(root.right)
#      52
#
# <ipython-input-6-d204ca06a309> in print_tree(root)
#      47 def print_tree(root):
#      48     if root:
# ---> 49         print(root.val)
#      50         print_tree(root.left)
#      51         print_tree(root.right)
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/iostream.py in write(self, string)
#     400             is_child = (not self._is_master_process())
#     401             # only touch the buffer in the IO thread to avoid races
# --> 402             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     403             if is_child:
#     404                 # mp.Pool cannot be trusted to flush promptly (or ever),
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/iostream.py in schedule(self, f)
#     201             self._events.append(f)
#     202             # wake event thread (message content is ignored)
# --> 203             self._event_pipe.send(b'')
#     204         else:
#     205             f()
#
# /usr/local/lib/python3.10/dist-packages/zmq/sugar/socket.py in send(self, data, flags, copy, track, routing_id, group)
#     616                 )
#     617             data.group = group
# --> 618         return super().send(data, flags=flags, copy=copy, track=track)
#     619
#     620     def send_multipart(
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# /usr/local/lib/python3.10/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %% [markdown]
# Part **2**

# %%
import random
import time

class TreeNode:
    def __init__(self, val):
        self.val = val
        self.left = None
        self.right = None

def insert_node(root, val):
    if not root:
        return TreeNode(val)

    if val < root.val:
        root.left = insert_node(root.left, val)
    else:
        root.right = insert_node(root.right, val)

    return root

def build_tree(numbers):
    if not numbers:
        return None

    root = None
    for num in numbers:
        root = insert_node(root, num)

    return root

def bfs(root):
    if not root:
        return []

    queue = [root]
    result = []

    while queue:
        current = queue.pop(0)
        result.append(current.val)

        if current.left:
            queue.append(current.left)
        if current.right:
            queue.append(current.right)

    return result

def dfs_preorder(root):
    if not root:
        return []

    result = []
    stack = [root]

    while stack:
        current = stack.pop()
        result.append(current.val)

        if current.right:
            stack.append(current.right)
        if current.left:
            stack.append(current.left)

    return result

def dfs_inorder(root):
    if not root:
        return []

    result = []
    stack = []
    current = root

    while current or stack:
        while current:
            stack.append(current)
            current = current.left

        current = stack.pop()
        result.append(current.val)
        current = current.right

    return result

def dfs_postorder(root):
    if not root:
        return []

    result = []
    stack1 = [root]
    stack2 = []

    while stack1:
        current = stack1.pop()
        stack2.append(current)

        if current.left:
            stack1.append(current.left)
        if current.right:
            stack1.append(current.right)

    while stack2:
        result.append(stack2.pop().val)

    return result

# Example usage
numbers_1000 = [random.randint(1, 1000) for _ in range(1000)]
tree_1000 = build_tree(numbers_1000)

numbers_40000 = [random.randint(1, 40000) for _ in range(40000)]
tree_40000 = build_tree(numbers_40000)

numbers_80000 = [random.randint(1, 80000) for _ in range(80000)]
tree_80000 = build_tree(numbers_80000)

numbers_200000 = [random.randint(1, 200000) for _ in range(200000)]
tree_200000 = build_tree(numbers_200000)



# Measure BFS execution time
start_time = time.time()
bfs_result_1000 = bfs(tree_1000)
end_time = time.time()
execution_time = end_time - start_time
print("BFS Execution Time for numbers_1000:", execution_time)

start_time = time.time()
bfs_result_40000 = bfs(tree_40000)
end_time = time.time()
execution_time = end_time - start_time
print("BFS Execution Time for numbers_40000:", execution_time)

start_time = time.time()
bfs_result_80000 = bfs(tree_80000)
end_time = time.time()
execution_time = end_time - start_time
print("BFS Execution Time for numbers_80000:", execution_time)

start_time = time.time()
bfs_result_200000 = bfs(tree_200000)
end_time = time.time()
execution_time = end_time - start_time
print("BFS Execution Time for numbers_200000:", execution_time)

start_time = time.time()
bfs_result_1000000 = bfs(tree_1000000)
end_time = time.time()
execution_time = end_time - start_time
print("BFS Execution Time for numbers_1000000:", execution_time)

# Measure DFS execution time
start_time = time.time()
dfs_result_1000 = dfs_preorder(tree_1000)
end_time = time.time()
execution_time = end_time - start_time
print("DFS Execution Time for numbers_1000:", execution_time)

start_time = time.time()
dfs_result_40000 = dfs_preorder(tree_40000)
end_time = time.time()
execution_time = end_time - start_time
print("DFS Execution Time for numbers_40000:", execution_time)

start_time = time.time()
dfs_result_80000 = dfs_preorder(tree_80000)
import random
import time

class TreeNode:
    def __init__(self, val):
        self.val = val
        self.left = None
        self.right = None

def insert_node(root, val):
    if not root:
        return TreeNode(val)

    if val < root.val:
        root.left = insert_node(root.left, val)
    else:
        root.right = insert_node(root.right, val)

    return root

def build_tree(numbers):
    if not numbers:
        return None

    root = None
    for num in numbers:
        root = insert_node(root, num)

    return root

def bfs(root):
    if not root:
        return []

    queue = [root]
    result = []

    while queue:
        current = queue.pop(0)
        result.append(current.val)

        if current.left:
            queue.append(current.left)
        if current.right:
            queue.append(current.right)

    return result

def dfs_preorder(root):
    if not root:
        return []

    result = []
    stack = [root]

    while stack:
        current = stack.pop()
        result.append(current.val)

        if current.right:
            stack.append(current.right)
        if current.left:
            stack.append(current.left)

    return result

def dfs_inorder(root):
    if not root:
        return []

    result = []
    stack = []
    current = root

    while current or stack:
        while current:
            stack.append(current)
            current = current.left

        current = stack.pop()
        result.append(current.val)
        current = current.right

    return result

def dfs_postorder(root):
    if not root:
        return []

    result = []
    stack1 = [root]
    stack2 = []

    while stack1:
        current = stack1.pop()
        stack2.append(current)

        if current.left:
            stack1.append(current.left)
        if current.right:
            stack1.append(current.right)

    while stack2:
        result.append(stack2.pop().val)

    return result

# Example usage
numbers_1000 = [random.randint(1, 1000) for _ in range(1000)]
tree_1000 = build_tree(numbers_1000)

numbers_40000 = [random.randint(1, 40000) for _ in range(40000)]
tree_40000 = build_tree(numbers_40000)

numbers_80000 = [random.randint(1, 80000) for _ in range(80000)]
tree_80000 = build_tree(numbers_80000)

numbers_200000 = [random.randint(1, 200000) for _ in range(200000)]
tree_200000 = build_tree(numbers_200000)

numbers_1000000 = [random.randint(1, 1000000) for _ in range(1000000)]
tree_1000000 = build_tree(numbers_1000000)

# Measure BFS execution time
start_time = time.time()
bfs_result_1000 = bfs(tree_1000)
end_time = time.time()
execution_time = end_time - start_time
print("BFS Execution Time for numbers_1000:", execution_time)

start_time = time.time()
bfs_result_40000 = bfs(tree_40000)
end_time = time.time()
execution_time = end_time - start_time
print("BFS Execution Time for numbers_40000:", execution_time)

start_time = time.time()
bfs_result_80000 = bfs(tree_80000)
end_time = time.time()
execution_time = end_time - start_time
print("BFS Execution Time for numbers_80000:", execution_time)

start_time = time.time()
bfs_result_200000 = bfs(tree_200000)
end_time = time.time()
execution_time = end_time - start_time
print("BFS Execution Time for numbers_200000:", execution_time)

start_time = time.time()
bfs_result_1000000 = bfs(tree_1000000)
end_time = time.time()
execution_time = end_time - start_time
print("BFS Execution Time for numbers_1000000:", execution_time)

# Measure DFS execution time
start_time = time.time()
dfs_result_1000 = dfs_preorder(tree_1000)
end_time = time.time()
execution_time = end_time - start_time
print("DFS Execution Time for numbers_1000:", execution_time)

start_time = time.time()
dfs_result_40000 = dfs_preorder(tree_40000)
end_time = time.time()
execution_time = end_time - start_time
print("DFS Execution Time for numbers_40000:", execution_time)

start_time = time.time()
dfs_result_80000 = dfs_preorder(tree_80000)
end_time = time.time()
execution_time = end_time - start_time
print("DFS Execution Time for numbers_80000:", execution_time)
# Out:
# BFS Execution Time for numbers_1000: 0.0005884170532226562
# BFS Execution Time for numbers_40000: 0.11741876602172852
# BFS Execution Time for numbers_80000: 0.11957788467407227
# BFS Execution Time for numbers_200000: 0.5308282375335693
# BFS Execution Time for numbers_1000000: 11.298962593078613
# DFS Execution Time for numbers_1000: 0.0005817413330078125
# DFS Execution Time for numbers_40000: 0.02741098403930664
# BFS Execution Time for numbers_1000: 0.0005800724029541016
# BFS Execution Time for numbers_40000: 0.03989052772521973
# BFS Execution Time for numbers_80000: 0.7045447826385498
# BFS Execution Time for numbers_200000: 0.5893476009368896
# BFS Execution Time for numbers_1000000: 10.316389560699463
# DFS Execution Time for numbers_1000: 0.0006234645843505859
# DFS Execution Time for numbers_40000: 0.02471613883972168
# DFS Execution Time for numbers_80000: 0.057790279388427734

# %% [markdown]
# PART **3**

# %%
import random
import time

def bfs(lis, goal):
    if not lis:
        return None

    queue = [(lis, 0)]
    visited = set()

    while queue:
        current, depth = queue.pop(0)
        visited.add(tuple(current))

        if current[-220:] == goal:
            return depth

        for i in range(len(current)):
            new_list = current[:i] + current[i+1:]
            if tuple(new_list) not in visited:
                queue.append((new_list, depth + 1))

    return -1

def dfs(lis, goal):
    if not lis:
        return None

    stack = [(lis, 0)]
    visited = set()

    while stack:
        current, depth = stack.pop()
        visited.add(tuple(current))

        if current[-220:] == goal:
            return depth

        for i in range(len(current)):
            new_list = current[:i] + current[i+1:]
            if tuple(new_list) not in visited:
                stack.append((new_list, depth + 1))

    return -1

# Example usage
random.seed(42)  # Set random seed for reproducibility

# Generate a random set of numbers
total_len = 1000
lis = [random.randint(1, 1000) for _ in range(total_len)]

goal = lis[total_len - 220:]

# Measure BFS execution time
start_time = time.time()
bfs_depth = bfs(lis, goal)
end_time = time.time()
execution_time = end_time - start_time
print("BFS Execution Time:", execution_time)
print("BFS Depth:", bfs_depth)

# Measure DFS execution time
start_time = time.time()
dfs_depth = dfs(lis, goal)
end_time = time.time()
execution_time = end_time - start_time
print("DFS Execution Time:", execution_time)
print("DFS Depth:", dfs_depth)
# Out:
# BFS Execution Time: 6.961822509765625e-05
# BFS Depth: 0
# DFS Execution Time: 8.416175842285156e-05
# DFS Depth: 0

# %% [markdown]
# PART5

# %%
import random
import time
import matplotlib.pyplot as plt

def bfs(lis, goal):
    if not lis:
        return None

    queue = [(lis, 0)]
    visited = set()

    while queue:
        current, depth = queue.pop(0)
        visited.add(tuple(current))

        if current[-220:] == goal:
            return depth

        for i in range(len(current)):
            new_list = current[:i] + current[i+1:]
            if tuple(new_list) not in visited:
                queue.append((new_list, depth + 1))

    return -1

def dfs(lis, goal):
    if not lis:
        return None

    stack = [(lis, 0)]
    visited = set()

    while stack:
        current, depth = stack.pop()
        visited.add(tuple(current))

        if current[-220:] == goal:
            return depth

        for i in range(len(current)):
            new_list = current[:i] + current[i+1:]
            if tuple(new_list) not in visited:
                stack.append((new_list, depth + 1))

    return -1

# Example usage
random.seed(42)  # Set random seed for reproducibility

# Input sizes
input_sizes = [1000, 40000, 80000, 200000, 1000000]

# Execution times
bfs_execution_times = []
dfs_execution_times = []

for total_len in input_sizes:
    lis = [random.randint(1, 1000) for _ in range(total_len)]
    goal = lis[total_len - 220:]

    # Measure BFS execution time
    start_time = time.time()
    bfs_depth = bfs(lis, goal)
    end_time = time.time()
    bfs_execution_time = end_time - start_time
    bfs_execution_times.append(bfs_execution_time)

    # Measure DFS execution time
    start_time = time.time()
    dfs_depth = dfs(lis, goal)
    end_time = time.time()
    dfs_execution_time = end_time - start_time
    dfs_execution_times.append(dfs_execution_time)

# Plotting the bar chart
plt.bar(input_sizes, bfs_execution_times, label='BFS')
plt.bar(input_sizes, dfs_execution_times, label='DFS')
plt.xlabel('Input Size')
plt.ylabel('Execution Time (seconds)')
plt.title('Execution Time Comparison - BFS vs DFS')
plt.legend()
plt.show()

# %% [markdown]
# TASK 3

# %%
import heapq

# Define the maze as a 2D grid with nodes represented by characters
maze = [
    ['A', ' ', ' ', ' ', ' ', ' ', ' '],
    ['#', '#', ' ', '#', '#', '#', '#'],
    [' ', ' ', ' ', ' ', ' ', ' ', ' '],
    ['#', '#', ' ', '#', '#', '#', '#'],
    [' ', ' ', ' ', ' ', ' ', ' ', ' '],
    ['#', '#', ' ', '#', '#', '#', '#'],
    [' ', ' ', ' ', ' ', ' ', ' ', ' '],
    ['#', '#', ' ', '#', '#', '#', '#'],
    [' ', ' ', ' ', ' ', ' ', ' ', ' '],
    ['#', '#', ' ', '#', '#', '#', '#'],
    [' ', ' ', ' ', ' ', ' ', ' ', ' '],
    ['#', '#', 'Y', '#', '#', '#', '#']
]

# Define the heuristic function as the Manhattan distance between two points
def heuristic(node, goal):
    x1, y1 = node
    x2, y2 = goal
    return abs(x1 - x2) + abs(y1 - y2)

# Define the A* search algorithm
def astar_search(maze, start, goal):
    # Define the directions: Up, Down, Left, Right
    directions = [(-1, 0), (1, 0), (0, -1), (0, 1)]

    # Initialize the priority queue with the start node
    queue = [(0, start)]
    heapq.heapify(queue)

    # Initialize the cost and came_from dictionaries
    cost = {start: 0}
    came_from = {start: None}

    while queue:
        # Get the node with the lowest priority (cost + heuristic)
        current_cost, current_node = heapq.heappop(queue)

        # Check if the current node is the goal
        if current_node == goal:
            break

        # Explore the neighbors of the current node
        for dx, dy in directions:
            x, y = current_node
            neighbor = (x + dx, y + dy)

            # Check if the neighbor is a valid node
            if 0 <= neighbor[0] < len(maze) and 0 <= neighbor[1] < len(maze[0]) and maze[neighbor[0]][neighbor[1]] != '#':
                # Calculate the cost of reaching the neighbor node
                new_cost = cost[current_node] + 1

                # Update the cost and came_from dictionaries if the new cost is lower
                if neighbor not in cost or new_cost < cost[neighbor]:
                    cost[neighbor] = new_cost
                    priority = new_cost + heuristic(neighbor, goal)
                    heapq.heappush(queue, (priority, neighbor))
                    came_from[neighbor] = current_node

    # Reconstruct the path from the goal to the start if a path exists
    if goal in came_from:
        path = []
        current_node = goal
        while current_node != start:
            path.append(current_node)
            current_node = came_from[current_node]
        path.append(start)

        # Reverse the path to obtain the correct order
        path.reverse()

        return path
    else:
        return None

# Define the start and goal positions
start = (0, 0)
goal = (len(maze) - 1, len(maze[0]) - 1)

# Find the path using A* search
path = astar_search(maze, start, goal)

# Print the resulting path if it exists
if path is not None:
    for node in path:
        x, y = node
        maze[x][y] = '*'

    for row in maze:
        print(' '.join(row))
else:
    print("No path found.")
# Out:
# No path found.

# %% [markdown]
# TASK 4
